# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
# Charger les données
data_automaton_time = pd.read_csv("./automaton/automaton_time_results.csv")
data_automaton_memory = pd.read_csv("./automaton/automaton_memory_results.csv")

# Convertir les temps en ms
data_automaton_time['Temps d\'exécution'] = data_automaton['Temps d\'exécution'] / 1000

# Trier les données par ordre croissant
data_automaton_time = data_automaton_time.sort_values(by='Nombre de lignes', ascending=True)
data_automaton_memory = data_automaton_memory.sort_values(by='Longueur du pattern', ascending=True)

# Graphique 1 : Temps d'exécution en fonction du nombre de lignes
plt.figure(figsize=(10, 6))
plt.plot(data_automaton_time['Nombre de lignes'], data_automaton_time['Temps d\'exécution'])
plt.xlabel('Nombre de lignes', fontsize=16)
plt.ylabel('Temps d\'exécution (ms)', fontsize=16)
plt.title('Graphe du temps d\'exécution en fonction du nombre de lignes', fontsize=18)
plt.tick_params(axis='both', labelsize=14)
plt.grid(True)
plt.savefig("./graphes/temps_execution_automaton.jpg")
plt.show()

# Graphique 2 : Consommation mémoire en fonction de la longueur du pattern
plt.figure(figsize=(10, 6))
plt.plot(data_automaton_memory['Longueur du pattern'], data_automaton_memory['Consommation mémoire'], color='green')
plt.xlabel('Nombre d\'états', fontsize=16)
plt.ylabel('Consommation mémoire (Ko)', fontsize=16)
plt.title('Graphe de la consommation mémoire en fonction de la longueur du pattern', fontsize=18)
plt.tick_params(axis='both', labelsize=14)
plt.grid(True)
plt.savefig("./graphes/conso_memoire_automaton.jpg")
plt.show()

# %%
# Charger les données
data_kmp_time = pd.read_csv("./kmp/kmp_time_results.csv")
data_kmp_memory = pd.read_csv("./kmp/kmp_memory_results.csv")

# Convertir les temps en ms
data_kmp_time['Temps d\'exécution'] = data_kmp['Temps d\'exécution'] / 1000

# Trier les données par ordre croissant
data_kmp_time = data_kmp_time.sort_values(by='Nombre de lignes', ascending=True)
data_kmp_memory = data_kmp_memory.sort_values(by='Longueur du pattern', ascending=True)


# Graphique 1 : Temps d'exécution en fonction du nombre de lignes
plt.figure(figsize=(10, 6))
plt.plot(data_kmp_time['Nombre de lignes'], data_kmp_time['Temps d\'exécution'])
plt.xlabel('Nombre de lignes', fontsize=16)
plt.ylabel('Temps d\'exécution (ms)', fontsize=16)
plt.title('Graphe du temps d\'exécution en fonction du nombre de lignes', fontsize=18)
plt.tick_params(axis='both', labelsize=14)
plt.grid(True)
plt.savefig("./graphes/temps_execution_kmp.jpg")
plt.show()

# Graphique 2 : Consommation mémoire en fonction de la longueur du pattern
plt.figure(figsize=(10, 6))
plt.plot(data_kmp_memory['Longueur du pattern'], data_kmp_memory['Consommation mémoire'], color='green')
plt.xlabel('Nombre d\'états', fontsize=16)
plt.ylabel('Consommation mémoire (Ko)', fontsize=16)
plt.title('Graphe de la consommation mémoire en fonction de la longueur du pattern', fontsize=18)
plt.tick_params(axis='both', labelsize=14)
plt.grid(True)
plt.savefig("./graphes/conso_memoire_kmp.jpg")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[19], line 2
#       1 # Charger les données
# ----> 2 data_kmp_time = pd.read_csv("./automaton/kmp_time_results.csv")
#       3 data_kmp_memory = pd.read_csv("./automaton/kmp_memory_results.csv")
#       5 # Convertir les temps en ms
#
# ...

# %%
# Charger les données
data_egrep = pd.read_csv("./egrep/egrep_results.csv")

# Convertir les temps en ms
data_egrep['Temps d\'exécution'] = data_egrep['Temps d\'exécution'] / 1000

# Trier les données par ordre croissant selon le 'Nombre de lignes'
data_egrep = data_egrep.sort_values(by='Nombre de lignes', ascending=True)

# Graphique 1 : Temps d'exécution en fonction du nombre de lignes
plt.figure(figsize=(10, 6))
plt.plot(data_egrep['Nombre de lignes'], data_egrep['Temps d\'exécution'])
plt.xlabel('Nombre de lignes', fontsize=16)
plt.ylabel('Temps d\'exécution (ms)', fontsize=16)
plt.title('Graphe du temps d\'exécution en fonction du nombre de lignes', fontsize=18)
plt.tick_params(axis='both', labelsize=14)
plt.grid(True)
plt.savefig("./graphes/temps_execution_egrep.jpg")
plt.show()

# Graphique 2 : Consommation mémoire en fonction du nombre de lignes
plt.figure(figsize=(10, 6))
plt.plot(data_egrep['Nombre de lignes'], data_egrep['Consommation mémoire'], color='green')
plt.xlabel('Nombre de lignes', fontsize=16)
plt.ylabel('Consommation mémoire (Ko)', fontsize=16)
plt.title('Graphe de la consommation mémoire en fonction du nombre de lignes', fontsize=18)
plt.tick_params(axis='both', labelsize=14)
plt.grid(True)
plt.savefig("./graphes/conso_memoire_egrep.jpg")
plt.show()

# %%
# Calculer la moyenne des temps d'exécution pour chaque algorithme
moyenne_automaton = data_automaton['Temps d\'exécution'].mean()
moyenne_kmp = data_kmp['Temps d\'exécution'].mean()
moyenne_egrep = data_egrep['Temps d\'exécution'].mean()

# Créer un DataFrame pour les moyennes
moyennes = pd.DataFrame({'Algorithme': ['Automate', 'KMP', 'egrep'],
                            'Moyenne temps d\'exécution': [moyenne_automaton, moyenne_kmp, moyenne_egrep]})

# Créer le diagramme à barres
plt.figure(figsize=(8, 6))
plt.bar(moyennes['Algorithme'], moyennes['Moyenne temps d\'exécution'], color=['orange', 'blue', 'green'])
plt.xlabel('Algorithme', fontsize=14)
plt.ylabel('Moyenne des temps d\'exécution (ms)', fontsize=14)
plt.title('Comparaison des moyennes de temps d\'exécution entre les algorithmes', fontsize=14)
plt.tick_params(axis='both', labelsize=12)
plt.savefig("./graphes/moyenne_temps.jpg")
plt.show()

print("Moyenne des temps d'exécution avec automate :", moyenne_automaton, "ms")
print("Moyenne des temps d'exécution avec KMP :", moyenne_kmp, "ms")
print("Moyenne des temps d'exécution avec egrep :", moyenne_egrep, "ms")
# Out:
# Moyenne des temps d'exécution avec automate : 32.86124464926829 ms
# Moyenne des temps d'exécution avec KMP : 29.56259822292683 ms
# Moyenne des temps d'exécution avec egrep : 11.893269023414634 ms

# %%
# Calculer la moyenne de la consommation mémoire pour chaque algorithme
moyenne_memoire_automaton = data_automaton['Consommation mémoire'].mean()
moyenne_memoire_kmp = data_kmp['Consommation mémoire'].mean()
moyenne_memoire_egrep = data_egrep['Consommation mémoire'].mean()

# Créer un DataFrame pour les moyennes de consommation mémoire
moyennes_memoire = pd.DataFrame({'Algorithme': ['Automate', 'KMP', 'egrep'],
                                    'Moyenne consommation mémoire': [moyenne_memoire_automaton, moyenne_memoire_kmp, moyenne_memoire_egrep]})

# Créer le diagramme à barres
plt.figure(figsize=(8, 6))
plt.bar(moyennes_memoire['Algorithme'], moyennes_memoire['Moyenne consommation mémoire'], color=['orange', 'blue', 'green'])
plt.xlabel('Algorithme')
plt.ylabel('Moyenne des consommations mémoire (octets)')
plt.title('Comparaison des moyennes de consommation mémoire entre automate et KMP')
plt.savefig("graphes/moyenne_memoire.jpg")
plt.show()

print("Moyenne des consommations mémoire avec automate :", moyenne_memoire_automaton, "octets")
print("Moyenne des consommations mémoire avec KMP :", moyenne_memoire_kmp, "octets")
print("Moyenne des consommations mémoire avec egrep :", moyenne_memoire_egrep, "octets")
# Out:
# Moyenne des consommations mémoire avec automate : 6834204.780487805 octets
# Moyenne des consommations mémoire avec KMP : 7456049.097560976 octets
# Moyenne des consommations mémoire avec egrep : 4939064.853658536 octets

# %%
# Calculer l'écart type pour chaque mesure
ecart_type_welzl = data['Temps d\'exécution Welzl'].std()
ecart_type_naif = data['Temps d\'exécution naif'].std()
ecart_type_mem_welzl = data['Consommation mémoire Welzl'].std()
ecart_type_mem_naif = data['Consommation mémoire naif'].std()
ecart_type_erreur_rayon = data['Erreur rayon'].std()

# Créer un diagramme à bâtons pour les écarts types
mesures = ['Temps d\'exécution Welzl', 'Temps d\'exécution naif', 'Consommation mémoire Welzl', 'Consommation mémoire naif', 'Erreur rayon']
ecarts_types = [ecart_type_welzl, ecart_type_naif, ecart_type_mem_welzl, ecart_type_mem_naif, ecart_type_erreur_rayon]

plt.bar(mesures, ecarts_types)
plt.xlabel('Mesures')
plt.ylabel('Écart type')
plt.title('Écart type pour chaque mesure')
plt.xticks(rotation=45)
plt.show()

print("Écart type temps d\'exécution Welzl :", ecart_type_welzl)
print("Écart type temps d\'exécution naif :", ecart_type_naif)
print("Écart type consommation mémoire Welzl :", ecart_type_mem_welzl)
print("Écart type consommation mémoire naif :", ecart_type_mem_naif)
print("Écart type erreur rayon :", ecart_type_erreur_rayon)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 # Calculer l'écart type pour chaque mesure
# ----> 2 ecart_type_welzl = data['Temps d\'exécution Welzl'].std()
#       3 ecart_type_naif = data['Temps d\'exécution naif'].std()
#       4 ecart_type_mem_welzl = data['Consommation mémoire Welzl'].std()
#
# NameError: name 'data' is not defined
